# %%
import os

PROJECT_ROOT = r"C:/Users/sohel/Downloads/Ai_health/End-to-End-Kidney-disease-classification-Deep-learning"
os.chdir(PROJECT_ROOT)

print("Working directory:", os.getcwd())
# Out:
# Working directory: C:\Users\sohel\Downloads\Ai_health\End-to-End-Kidney-disease-classification-Deep-learning

# %%
from cnnClassifier.config.configuration import ConfigurationManager
from cnnClassifier.components.prepare_base_model import PrepareBaseModel

config = ConfigurationManager()
prepare_config = config.get_prepare_base_model_config()

prepare = PrepareBaseModel(prepare_config)
prepare.get_base_model()
prepare.update_base_model()
# Out:
# [2025-12-07 15:54:24,666: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-12-07 15:54:24,674: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-12-07 15:54:24,675: INFO: common: created directory at: artifacts]
# [2025-12-07 15:54:24,675: INFO: common: created directory at: artifacts/prepare_base_model]
# [2025-12-07 15:54:24,675: INFO: prepare_base_model: Loading base CNN model (e.g., VGG16 / MobileNet)...]
# [2025-12-07 15:54:24,858: INFO: prepare_base_model: Base model loaded successfully.]
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
# ...
