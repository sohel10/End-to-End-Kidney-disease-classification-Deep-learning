# %%
import os

PROJECT_ROOT = r"C:/Users/sohel/Downloads/Ai_health/End-to-End-Kidney-disease-classification-Deep-learning"
os.chdir(PROJECT_ROOT)

print("Working directory:", os.getcwd())
# Out:
# Working directory: C:\Users\sohel\Downloads\Ai_health\End-to-End-Kidney-disease-classification-Deep-learning

# %%
from cnnClassifier.config.configuration import ConfigurationManager
from cnnClassifier.components.prepare_callbacks import PrepareCallback

config = ConfigurationManager()
callback_config = config.get_prepare_callback_config()

callbacks = PrepareCallback(callback_config)
callback_list = callbacks.get_tb_ckpt_callbacks()

callback_list
# Out:
# [2025-12-07 15:54:36,237: INFO: common: yaml file: config\config.yaml loaded successfully]
# [2025-12-07 15:54:36,239: INFO: common: yaml file: params.yaml loaded successfully]
# [2025-12-07 15:54:36,239: INFO: common: created directory at: artifacts]
# [2025-12-07 15:54:36,239: INFO: common: created directory at: artifacts\prepare_callbacks\tensorboard]
# [2025-12-07 15:54:36,241: INFO: common: created directory at: artifacts\prepare_callbacks\checkpoints]
# [2025-12-07 15:54:36,242: INFO: prepare_callbacks: Returning TensorBoard + Checkpoint callbacks...]
# [2025-12-07 15:54:36,242: INFO: prepare_callbacks: Creating TensorBoard callback...]
# [2025-12-07 15:54:36,243: INFO: prepare_callbacks: Creating ModelCheckpoint callback...]
# [<keras.callbacks.TensorBoard at 0x16e586996f0>,
#  <keras.callbacks.ModelCheckpoint at 0x16e5869bac0>]
